# %% [markdown]
# # Analysis Notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import numpy as np
import time
# %matplotlib inline
plt.rc('font', family='serif')
plt.rc('xtick', labelsize='x-small')
plt.rc('ytick', labelsize='x-small')
plt.rc('font', size = 20)
plt.rc('text', usetex=True)
#!conda info

# %% [markdown]
# ## Configeration

# %%
# Numbers
hv = 500         # n of HVs
av = 500         # n of AVs
N = 500           # n of Days

# Human Parameters
hv_err = 5        # error term on HV time perception ~N(0, hv_err)
hv_theta = .5     # rationality
hv_beta = .5      # prob of change route
hv_len = 3        # Memory lenth
hv_atis_bais = 0  # bias*prevTT + (1-bais)*memTT

# AV Parameters
av_err = 0
av_theta = 1
av_len = 1000     
av_atis_bias = 0

path = f"data/sim-ROUTES-N{N}-hv{hv}at{hv_err}_{hv_theta}_{hv_beta}_{hv_len}_{hv_atis_bais}-av{av}at{av_err}_{av_theta}_{av_len}_{av_atis_bias}.pickle"

# %% [markdown]
# ## Plots

# %%
# Def variables
#variable = list(np.linspace(0.1, 5.0, 10))
variable = [0.01, 0.05, 0.1, .2, .3, .4, .5, 1, 2, 3]    # hv Theta Var or av
#variable = list(np.linspace(0, 1, 10))                   # hv Beta Var
#variable = list(np.linspace(0, 10, 10))                  # hv Err Var
#variable = list(np.linspace(0, 20, 10))                   # hv len var
#variable = [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000] # hv/av counts
var_len = range(len(variable))
tables = ["missing" for i in var_len]

# %%
# Get data for variables
for i in var_len:
    av_theta = variable[i]
    path = f"data/sim-ROUTES-N{N}-hv{hv}at{hv_err}_{hv_theta}_{hv_beta}_{hv_len}_{hv_atis_bais}-av{av}at{av_err}_{av_theta}_{av_len}_{av_atis_bias}.pickle"
    tables[i] = pickle.load(open(path, "rb" ))

# %%
iii = 0
for table in tables:
    table.plot(title=f"{iii}")
    iii +=1

# %%
# Table tab
tab = 9
vari = variable[tab]
test = tables[tab]
means = [test[f'Route{i}'].tail(250).mean() for i in range(6) ]


#set up figure
fig, ax = plt.subplots(figsize=(10,7))
ax.set(xlim=[0, 100], ylim=[0,1000], xlabel='Day', ylabel='Traffic',
   title='Traffic On Each Route: default simulation  ')

# Add data
test.plot(ax=ax, style = 'o-' ,markersize=3)
ax.legend(bbox_to_anchor=(1.25, 1), fontsize=16)
for mean in means:
    ax.axhline(mean, ls='--', color='k')   
#ax.grid()
#fig.savefig('figs/default.png', transparent=False, dpi=80, bbox_inches="tight")
print(means)
# Out:
# [332.54, 119.58, 93.34, 45.98, 191.108, 217.452]

# %%
#set up figure
fig, axs = plt.subplots(2,2, figsize=(10,7))
fig.suptitle('Traffic On Routes 0,2')
fig.tight_layout(pad=3.0)
axgen = (ax for ax in axs.flatten())

# Add data
for tab in [0,2,7,9]:
    
    ax = next(axgen)
    vari = variable[tab]  #hv
    test = tables[tab]    #av  
    mean0 = test['Route0'].tail(250).mean()    
    mean2 = test['Route2'].tail(250).mean()
    
    test['Route0'].plot(ax=ax, style = 'o-' ,markersize=3, legend = False)
    test['Route2'].plot(ax=ax, style = 'o-' ,markersize=3, legend = False)
    #ax.axhline(mean0 , ls='--', color='k')
    #ax.axhline(mean2 , ls='--', color='k')  
    #ax.text(101,mean0,f'-{round(mean0,1)}')
   # ax.text(101,mean2,f'-{round(mean2,1)}')
    
    if tab == 0:
        ax.set(xlim=[0, 100], ylim=[0,1000], ylabel='Traffic', title=f'theta av = {vari}' )
    if tab == 2:
        ax.set(xlim=[0, 100], ylim=[0,1000], title=f'theta av = {vari}')
    if tab == 7:
        ax.set(xlim=[0, 100], ylim=[0,1000],xlabel='Day', ylabel='Traffic', title=f'theta av = {vari}')
    if tab == 9:
        ax.set(xlim=[0, 100], ylim=[0,1000],xlabel='Day',  title=f'theta av = {vari}')
    
    fig.legend(['Route0','Route2'], bbox_to_anchor=(.87, .80), fontsize=16, borderaxespad=0.)
    #ax.grid()
    if tab == 0 or tab==10:
        print(mean0)
        print(mean2)
fig.savefig(f'figs/av_th_grid.png', transparent=False, dpi=80, bbox_inches="tight")
# Out:
# 228.728
# 158.812

# %%
#set up figure
fig, ax = plt.subplots(figsize=(10,7))
ax.set(xlim=[0, 500], ylim=[0,1000], xlabel='Day', ylabel='Traffic',
       title="Traffic On Route 0 for different AV Theta" )
colors = plt.cm.bwr(np.linspace(0,1,11))
#colors = (elem for elem in colors)
lables = (f"Theta = {elem}" for elem in [0.01, 3])
#(f"Theta = {elem}" for elem in reversed(variable))

# Add data
for test in [tables[0], tables[9]]:
    #col = next(colors)
    mean = test['Route0'].tail(520).mean()
    print(mean)
    std = test['Route0'].tail(50).std()
    test['Route0'].plot(ax=ax, style = "o-" , markersize=3, alpha = 1, label = next(lables) )
    ax.axhline(mean ,  ls='--', color = col)
    #ax.axhline(mean  - 2*std , ls='--', color = col)
ax.legend(bbox_to_anchor=(1, 1), fontsize=16) 
#color = col
#fig.savefig('figs/av_th3001_std.png', transparent=False, dpi=200, bbox_inches="tight")
# Out:
# 228.004
# 341.398

# %%
#set up data list
data = reversed([table['Route0'] for table in tables])
labels = ("theta av ="+ f" {elem}" for elem in reversed(variable))
depth = 5
y = [i for i in range(depth, 500)]

#set up figure
fig, ax = plt.subplots(figsize=(10,7))
ax.set(xlim=[0, 500], ylim=[0,400], xlabel='Day', ylabel='Standard Deviation of last 5 days',
       title= "Flow Std On Route 0 for each theta av" )
#ax.set_xlabel(xlabel='Day', fontsize=20)
colors = plt.cm.bwr(np.linspace(0,1,11))
colors = (elem for elem in reversed(colors))

# Add data
for series in data:
    col = next(colors)
    label = next(labels)
    
    points = []
    for i in range(depth,500):
        point = series[i-depth : i].std()
        points.append(point)
    ax.plot(y, points, markersize=3, color = col, alpha = 1, label = label )
    
ax.legend(bbox_to_anchor=(1, 1), fontsize=18) 
fig.savefig('figs/av_th_std.png', transparent=False, dpi=200, bbox_inches="tight")

# %%
test = tables[5]

all_means = pd.DataFrame(columns = [f'Route{i}' for i in range(6) ])
mmeans = [test[f'Route{i}'].tail(250).mean() for i in range(6) ]

i = 0
for tabb in tables:
    means = [tabb[f'Route{i}'].tail(250).mean() for i in range(6) ]
    all_means.loc[i] = means
    i = i+1
    print(means)
    
fig, ax = plt.subplots(figsize=(10,8))
ax.set(xlim=[0, 11], ylim=[0,400], xlabel='Day', ylabel='Standard Deviation of last 5 days',
        title= "Flow Std On Route 0 for each $N_{hv},N_{av}$" )
for mmean in mmeans:
    ax.axhline(mmean, ls='--', color='k')   
all_means.plot(ax=ax, style = 'x-')
ax.legend(bbox_to_anchor=(1.33, 1.02), fontsize=18)
# Out:
# [228.728, 139.264, 158.812, 126.664, 148.8, 197.732]
# [243.136, 131.7, 155.904, 120.944, 148.692, 199.624]
# [254.868, 130.384, 147.368, 111.324, 153.56, 202.496]
# [263.308, 122.132, 148.804, 107.66, 148.336, 209.76]
# [275.876, 117.26, 144.32, 102.528, 151.292, 208.724]
# [281.584, 116.844, 139.332, 94.668, 157.364, 210.208]
# [289.084, 112.3, 138.224, 93.26, 156.716, 210.416]
# [306.94, 112.468, 122.18, 74.144, 171.588, 212.68]
# [329.056, 117.552, 100.336, 53.036, 182.484, 217.536]
# [332.54, 119.58, 93.34, 45.98, 191.108, 217.452]

# %%
#set up data list
data = [table['Route0'] for table in tables]
means = [test[f'Route{i}'].tail(250).mean() for i in range(6) ]
labels = ("$N_{hv}$ ="+ f" {elem}" for elem in variable)
depth = 10
y = [i for i in range(depth, 500)]

#set up figure
fig, ax = plt.subplots(figsize=(10,8))
ax.set(xlim=[0, 100], ylim=[0,1000], xlabel='Day', ylabel='Standard Deviation of last 5 days',
       title= "Flow Std On Route 0 for each $N_{hv},N_{av}$" )
#ax.set_xlabel(xlabel='Day', fontsize=20)
colors = plt.cm.bwr(np.linspace(0,1,11))
colors = (elem for elem in colors)

# Add data
for series in data:
    col = next(colors)
    label = next(labels)
    
    points = []
    for i in range(depth,500):
        point = series[i-depth : i].mean()
        points.append(point)
    ax.plot(y, points, markersize=3, color = col, alpha = 1, label = label )
for mean in means:
    ax.axhline(mean, ls='--', color='k')   
    
#ax.legend(bbox_to_anchor=(1.33, 1.02), fontsize=18) 
#fig.savefig('figs/hv_av_std.png', transparent=False, dpi=80, bbox_inches="tight")

# %%
times_dir = f"data/sim-TIMES-N{N}-hv{hv}at{hv_err}_{hv_theta}_{hv_beta}_{hv_len}_{hv_atis_bais}-av{av}at{av_err}_{av_theta}_{av_len}_{av_atis_bias}.pickle"
time_routes = pickle.load(open(times_dir, "rb" ))
time_means = list(time_routes.tail(250).mean())


fig, ax = plt.subplots(figsize=(10,7))
ax.set(xlim=[0, 500], ylim=[0,300], xlabel='Day', ylabel='Travel time',
   title='Travel Time On Each Route: default simulation  ')

# Add data
time_routes.plot(ax=ax)
for m in time_means:
    ax.axhline(m, ls='--', color='k') 

ax.legend(bbox_to_anchor=(1.25, 1), fontsize=16) 

#fig.savefig('figs/default_tts.png', transparent=False, dpi=80, bbox_inches="tight")
#ax.grid()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-80c8814045bf> in <module>
#       1 times_dir = f"data/sim-TIMES-N{N}-hv{hv}at{hv_err}_{hv_theta}_{hv_beta}_{hv_len}_{hv_atis_bais}-av{av}at{av_err}_{av_theta}_{av_len}_{av_atis_bias}.pickle"
# ----> 2 time_routes = pickle.load(open(times_dir, "rb" ))
#       3 time_means = list(time_routes.tail(250).mean())
#       4
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/sim-TIMES-N500-hv500at5_0.5_0.5_3_0-av500at0_3_1000_0.pickle'

# %%
list(time_routes.tail(250).mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-597f0b9b03d7> in <module>
# ----> 1 list(time_routes.tail(250).mean())
#
# NameError: name 'time_routes' is not defined
